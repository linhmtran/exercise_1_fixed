# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
#import matplotlib.pyplot as plt
#%matplotlib inline
import csv

# %% [markdown]
# # Hospitals

# %%
h = pd.read_csv('Hospital_General_Information.csv', index_col=False)
h.head()
# Out:
#    Provider ID                   Hospital Name                     Address  \
# 0        10005   MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 1        10012  DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE
# 2        10032                WEDOWEE HOSPITAL       209 NORTH MAIN STREET
# 3        10095            HALE COUNTY HOSPITAL            508 GREEN STREET
# 4        10131        CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE
#
#          City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0        BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 1  FORT PAYNE    AL     35968     DE KALB    2568453150  Acute Care Hospitals
# 2     WEDOWEE    AL     36278    RANDOLPH    2563572111  Acute Care Hospitals
# 3  GREENSBORO    AL     36744        HALE    3346243024  Acute Care Hospitals
# 4  HUNTSVILLE    AL     35801     MADISON    2568823100  Acute Care Hospitals
#
# ...

# %% [markdown]
# # Effective Care

# %%
e = pd.read_csv('Timely_and_Effective_Care_-_Hospital.csv', index_col=False)
e.head()
# Out:
#    Provider ID                  Hospital Name                     Address  \
# 0        10005  MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 1        10005  MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10005  MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 3        10005  MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 4        10005  MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
#
#    City State  ZIP Code County Name  Phone Number             Condition  \
# 0  BOAZ    AL     35957    MARSHALL    2565938310  Emergency Department
# 1  BOAZ    AL     35957    MARSHALL    2565938310  Emergency Department
# 2  BOAZ    AL     35957    MARSHALL    2565938310  Emergency Department
# 3  BOAZ    AL     35957    MARSHALL    2565938310       Preventive Care
# 4  BOAZ    AL     35957    MARSHALL    2565938310       Preventive Care
#
#                Measure ID                                    Measure Name  \
# ...

# %%
print(e['Score'].describe())
e['Score'].unique()
# Out:
# count            105864
# unique              591
# top       Not Available
# freq              52863
# Name: Score, dtype: object
# array(['240', '72', 'Very High (60,000+ patients annually)', '97', '80',
#        'Not Available', '113', '23', '67', '2', '86', '94', '98', '14',
#        '199', '54', 'Medium (20,000 - 39,999 patients annually)', '85',
#        '137', '32', '58', '100', '1', '12', '245', '82',
#        'Low (0 - 19,999 patients annually)', '95', '118', '25', '13', '44',
#        '5', '55', '66', '71', '127', '30', '76', '84', '328', '115',
#        'High (40,000 - 59,999 patients annually)', '99', '166', '64', '3',
#        '0', '92', '88', '63', '107', '22', '40', '91', '158', '316', '59',
#        '60', '83', '46', '324', '254', '110', '10', '262', '105', '19',
#        '338', '8', '216', '93', '332', '152', '160', '56', '18', '4',
#        '190', '53', '87', '28', '79', '96', '68', '89', '39', '38', '7',
# ...

# %%
print(e['Measure ID'].describe())
e['Measure ID'].unique()
# Out:
# count                     105864
# unique                        22
# top       IMM_3_OP_27_FAC_ADHPCT
# freq                        4812
# Name: Measure ID, dtype: object
# array(['ED_1b', 'ED_2b', 'EDV', 'IMM_2', 'IMM_3_OP_27_FAC_ADHPCT', 'OP_1',
#        'OP_18b', 'OP_2', 'OP_20', 'OP_21', 'OP_22', 'OP_23', 'OP_29',
#        'OP_30', 'OP_31', 'OP_3b', 'OP_4', 'OP_5', 'PC_01', 'STK_4',
#        'VTE_5', 'VTE_6'], dtype=object)

# %% [markdown]
# ## Surveys

# %%
s = pd.read_csv('hvbp_hcahps_05_28_2015.csv', index_col=False)
s.head()
# Out:
#    Provider Number                     Hospital Name  \
# 0            10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10005     MARSHALL MEDICAL CENTER SOUTH
# 2            10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3            10007          MIZELL MEMORIAL HOSPITAL
# 4            10008       CRENSHAW COMMUNITY HOSPITAL
#
#                       Address      City State ZIP Code County Name  \
# 0      1108 ROSS CLARK CIRCLE    Dothan    AL    36301     HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH      Boaz    AL    35957    MARSHALL
# 2          205 MARENGO STREET  Florence    AL    35631  LAUDERDALE
# 3               702 N MAIN ST       Opp    AL    36467   COVINGTON
# 4         101 HOSPITAL CIRCLE   Luverne    AL    36049    CRENSHAW
#
#   Communication with Nurses Achievement Points  \
# 0                                  0 out of 10
# 1                                  7 out of 10
# 2                                  1 out of 10
# ...

# %%
print(s['Overall Rating of Hospital Achievement Points'].describe())
s['Overall Rating of Hospital Achievement Points'].unique()
# Out:
# count            3074
# unique             12
# top       0 out of 10
# freq             1164
# Name: Overall Rating of Hospital Achievement Points, dtype: object
# array(['3 out of 10', '5 out of 10', '0 out of 10', '2 out of 10',
#        '1 out of 10', '4 out of 10', '9 out of 10', '6 out of 10',
#        '10 out of 10', '7 out of 10', 'Not Available', '8 out of 10'], dtype=object)

# %%
print(s['Overall Rating of Hospital Improvement Points'].describe())
s['Overall Rating of Hospital Improvement Points'].unique()
# Out:
# count           3074
# unique            11
# top       0 out of 9
# freq            1431
# Name: Overall Rating of Hospital Improvement Points, dtype: object
# array(['2 out of 9', '0 out of 9', '4 out of 9', '1 out of 9',
#        '8 out of 9', '5 out of 9', '7 out of 9', '9 out of 9',
#        '3 out of 9', 'Not Available', '6 out of 9'], dtype=object)

# %%
print(s['Overall Rating of Hospital Dimension Score'].describe())
s['Overall Rating of Hospital Dimension Score'].unique()
# Out:
# count            3074
# unique             12
# top       0 out of 10
# freq              784
# Name: Overall Rating of Hospital Dimension Score, dtype: object
# array(['3 out of 10', '5 out of 10', '0 out of 10', '4 out of 10',
#        '1 out of 10', '2 out of 10', '9 out of 10', '6 out of 10',
#        '10 out of 10', '7 out of 10', 'Not Available', '8 out of 10'], dtype=object)

# %%
print(s['HCAHPS Base Score'].describe())
s['HCAHPS Base Score'].unique()
# Out:
# count     3074
# unique      82
# top          8
# freq        86
# Name: HCAHPS Base Score, dtype: object
# array(['17', '51', '9', '40', '30', '11', '31', '10', '24', '34', '55',
#        '16', '45', '33', '47', '59', '38', '8', '27', '72', '80', '3',
#        '69', '21', '6', '32', '36', '39', '48', '14', '49', '29', '15',
#        '44', '37', '46', '42', 'Not Available', '35', '43', '62', '19',
#        '23', '58', '13', '7', '22', '26', '20', '4', '28', '2', '0', '1',
#        '25', '65', '67', '57', '5', '71', '12', '61', '18', '50', '56',
#        '41', '68', '77', '64', '79', '74', '75', '63', '52', '78', '60',
#        '54', '76', '53', '70', '73', '66'], dtype=object)

# %%
s['HCAHPS Base Score'].loc[s['HCAHPS Base Score'] == 'Not Available'].count()
# Out:
# 32

# %%
print(s['HCAHPS Consistency Score'].describe())
s['HCAHPS Consistency Score'].unique()
# Out:
# count     3074
# unique      21
# top         20
# freq       833
# Name: HCAHPS Consistency Score, dtype: object

# %%
survey['Provider Number'].describe()
# Out:
# count     3,074.00
# mean    261,522.02
# std     159,765.55
# min      10,001.00
# 25%     110,092.75
# 50%     260,021.00
# 75%     390,130.75
# max     670,085.00
# Name: Provider Number, dtype: float64

# %% [markdown]
# ## Complications

# %%
c = pd.read_csv('Complications_and_Deaths_-_Hospital.csv', index_col=False)
c.head()
# Out:
#    Provider ID                                  Hospital Name  \
# 0       223300  FRANCISCAN CHILDREN'S HOSPITAL & REHAB CENTER
# 1       230003     SPECTRUM HEALTH ZEELAND COMMUNITY HOSPITAL
# 2       223303          SHRINERS' HOSPITAL FOR CHILDREN (THE)
# 3       230003     SPECTRUM HEALTH ZEELAND COMMUNITY HOSPITAL
# 4       230036            MIDMICHIGAN MEDICAL CENTER - ALPENA
#
#               Address         City State  ZIP Code County Name  Phone Number  \
# 0    30 WARREN STREET     BRIGHTON    MA      2135     SUFFOLK    6172543800
# 1       8333 FELCH ST      ZEELAND    MI     49464      OTTAWA    6167724644
# 2    516 CAREW STREET  SPRINGFIELD    MA      1104     HAMPDEN    4137872000
# 3       8333 FELCH ST      ZEELAND    MI     49464      OTTAWA    6167724644
# 4  1501 W CHISHOLM ST       ALPENA    MI     49707      ALPENA    9893567390
#
#                                         Measure Name       Measure ID  \
# ...

# %%
c.describe()
# Out:
#        Provider ID  ZIP Code     Phone Number
# count    91,428.00 91,428.00        91,428.00
# mean    268,136.62 53,972.20 5,848,062,460.36
# std     157,122.36 26,909.11 2,332,079,774.85
# min      10,001.00    603.00   936,933,841.00
# 25%     140,183.50 33,015.25 4,014,532,518.75
# 50%     260,037.00 55,404.00 6,053,413,350.00
# 75%     390,220.50 76,028.00 7,877,583,105.00
# max     670,120.00 99,929.00 9,898,943,000.00

# %%
print(c['Measure ID'].describe())
c['Measure ID'].unique()
# Out:
# count           91428
# unique             19
# top       PSI_3_ULCER
# freq             4812
# Name: Measure ID, dtype: object
# array(['PSI_4_SURG_COMP', 'PSI_3_ULCER', 'PSI_6_IAT_PTX', 'MORT_30_STK',
#        'PSI_10_POST_KIDNEY', 'PSI_9_POST_HEM', 'PSI_15_ACC_LAC',
#        'PSI_13_POST_SEPSIS', 'PSI_8_POST_HIP', 'PSI_11_POST_RESP',
#        'COMP_HIP_KNEE', 'MORT_30_AMI', 'MORT_30_CABG', 'MORT_30_COPD',
#        'MORT_30_HF', 'MORT_30_PN', 'PSI_12_POSTOP_PULMEMB_DVT',
#        'PSI_14_POSTOP_DEHIS', 'PSI_90_SAFETY'], dtype=object)

# %%
c1 = c.groupby(['Measure Name'])['Measure Name','Denominator','Score','Lower Estimate','Higher Estimate']
c1

# %% [markdown]
# # Measures

# %%
m = pd.read_csv('Measure_Dates.csv', index_col=False)
m.head()
# Out:
#                                         Measure Name  \
# 0                             ACS Participation data
# 1  Fibrinolytic Therapy Received Within 30 Minute...
# 2  Fibrinolytic Therapy Received Within 30 Minute...
# 3                                       Combined SSI
# 4                                       Combined SSI
#
#                                     Measure ID Measure Start Quarter  \
# 0                                 ACS_REGISTRY                4Q2015
# 1                         AMI_7a_HVBP_Baseline                1Q2013
# 2                      AMI_7a_HVBP_Performance                1Q2015
# 3                   Combined_SSI_Measure_Score                1Q2013
# 4  Combined_SSI_Measure_Score_HVBP_Performance                1Q2015
#
#   Measure Start Date Measure End Quarter Measure End Date
# 0         10/01/2015              3Q2016       09/30/2016
# 1         01/01/2013              4Q2013       12/31/2013
# ...

# %%
m.describe()
# Out:
#                   Measure Name    Measure ID Measure Start Quarter  \
# count                      163           163                   163
# unique                     133           161                    13
# top     Influenza Immunization  Linear Score                1Q2015
# freq                         4             2                    43
#
#        Measure Start Date Measure End Quarter Measure End Date
# count                 163                 163              163
# unique                 13                  10               10
# top            01/01/2015              4Q2015       12/31/2015
# freq                   43                  50               50

# %%
print(m['Measure ID'].describe())
m['Measure ID'].unique()
# Out:
# count              163
# unique             161
# top       Linear Score
# freq                 2
# Name: Measure ID, dtype: object
# array(['ACS_REGISTRY', 'AMI_7a_HVBP_Baseline', 'AMI_7a_HVBP_Performance',
#        'Combined_SSI_Measure_Score',
#        'Combined_SSI_Measure_Score_HVBP_Performance', 'COMP_HIP_KNEE',
#        'Composite 1 Q1 to Q3', 'Composite 2 Q5 to Q7',
#        'Composite 3 Q4 & Q11', 'Composite 4 Q13 & Q14',
#        'Composite 5 Q16 & Q17', 'Composite 6 Q19 & Q20',
#        'Composite 7 (Q23 to 25)', 'ED_1b', 'ED_2b', 'EDAC_30_AMI',
#        'EDAC_30_HF', 'EDV', 'FUH_30', 'FUH_7', 'HACRP_CAUTI', 'HACRP_CDI',
#        'HACRP_CLABSI', 'HACRP_D1', 'HACRP_D2', 'HACRP_MRSA', 'HACRP_PSI90',
#        'HACRP_SSI', 'HACRP_Total', 'HAI_1', 'HAI_1_HVBP_Baseline',
#        'HAI_1_HVBP_Performance', 'HAI_2', 'HAI_2_HVBP_Baseline',
#        'HAI_2_HVBP_Performance', 'HAI_3', 'HAI_3_HVBP_Baseline',
#        'HAI_3_HVBP_Performance', 'HAI_4', 'HAI_4_HVBP_Baseline',
# ...
